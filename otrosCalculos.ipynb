# %% [markdown]
# # Notebook con ejecuciones auxiliares

# %%
import pandas as pd
import plotly.express as px
from utils.preparacionDatos import crear_dataset

# %%
data = crear_dataset('raw_dataset', exportar = 'N')

# %%
fig = px.scatter(data.loc[data.CURSO == '19/20'], x="DATE", y="SCORE")
fig.show()
